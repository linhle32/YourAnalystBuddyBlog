# %% [markdown]
# The complete explanation for this notebook is at https://youranalystbuddy.com/text-data-in-pandas/
#
# ## Data types for text

# %%
import pandas as pd

students = pd.read_csv('students_standing.csv')
students.head(n=3)
# Out:
#    StudentID FirstName      LastName  HSGPA  FYGPA Standing
# 0  202005537    Eunice        Ehmann   2.47   2.42  average
# 1  202008560    Hobert  Schoenberger   2.27   2.05  average
# 2  202004948  Nicholas         Sizer   4.00   3.96     good

# %%
students.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   StudentID  200 non-null    int64
#  1   FirstName  200 non-null    object
#  2   LastName   200 non-null    object
#  3   HSGPA      200 non-null    float64
#  4   FYGPA      200 non-null    float64
#  5   Standing   200 non-null    object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 9.5+ KB

# %%
to_string_cols = ['StudentID','FirstName','LastName','Standing']
students[to_string_cols] = students[to_string_cols].astype('string')
students.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   StudentID  200 non-null    string
#  1   FirstName  200 non-null    string
#  2   LastName   200 non-null    string
#  3   HSGPA      200 non-null    float64
#  4   FYGPA      200 non-null    float64
#  5   Standing   200 non-null    string
# dtypes: float64(2), string(4)
# memory usage: 9.5 KB

# %% [markdown]
# ### Basic operations on text data

# %%
students['FullName'] = students['FirstName'] + ' ' + students['LastName']
students.head(n=5)
# Out:
#    StudentID FirstName      LastName  HSGPA  FYGPA Standing  \
# 0  202005537    Eunice        Ehmann   2.47   2.42  average
# 1  202008560    Hobert  Schoenberger   2.27   2.05  average
# 2  202004948  Nicholas         Sizer   4.00   3.96     good
# 3  202001207     Elvin        Foulks   3.16   2.64  average
# 4  202000260     Bruno         Viney   3.82   3.99     good
#
#               FullName
# 0        Eunice Ehmann
# 1  Hobert Schoenberger
# 2       Nicholas Sizer
# 3         Elvin Foulks
# 4          Bruno Viney

# %% [markdown]
# ### The str property

# %%
students['FirstName'].str[:4]
# Out:
# 0      Eunice
# 1      Hobert
# 2    Nicholas
# 3       Elvin
# Name: FirstName, dtype: string

# %%
students['Email'] = students['FirstName'].str[0] + students['LastName'].str[:5] \
    + students['StudentID'].str[-5:] + '@work.com'
students.head(3)
# Out:
#    StudentID FirstName      LastName  HSGPA  FYGPA Standing  \
# 0  202005537    Eunice        Ehmann   2.47   2.42  average
# 1  202008560    Hobert  Schoenberger   2.27   2.05  average
# 2  202004948  Nicholas         Sizer   4.00   3.96     good
#
#               FullName                 Email
# 0        Eunice Ehmann  EEhman05537@work.com
# 1  Hobert Schoenberger  HSchoe08560@work.com
# 2       Nicholas Sizer  NSizer04948@work.com

# %%
students['FirstName'].str.upper()
# Out:
# 0        EUNICE
# 1        HOBERT
# 2      NICHOLAS
# 3         ELVIN
# 4         BRUNO
#          ...
# 195       JUDGE
# 196     WINSTON
# 197    THADDEUS
# 198      WRIGHT
# 199      SIDNEY
# Name: FirstName, Length: 200, dtype: string

# %%
students['Email'].str.lower()
# Out:
# 0      eehman05537@work.com
# 1      hschoe08560@work.com
# 2      nsizer04948@work.com
# 3      efoulk01207@work.com
# 4      bviney00260@work.com
#                ...
# 195    jgrand00691@work.com
# 196    wkanek09695@work.com
# 197     tchen08725@work.com
# 198    wmarbu01120@work.com
# 199    ssienk09418@work.com
# Name: Email, Length: 200, dtype: string

# %%
students['StudentID'].str.removeprefix('2020')
# Out:
# 0      05537
# 1      08560
# 2      04948
# 3      01207
# 4      00260
#        ...
# 195    00691
# 196    09695
# 197    08725
# 198    01120
# 199    09418
# Name: StudentID, Length: 200, dtype: string

# %%
students['Email'].str.removesuffix('.com')
# Out:
# 0      EEhman05537@work
# 1      HSchoe08560@work
# 2      NSizer04948@work
# 3      EFoulk01207@work
# 4      BViney00260@work
#              ...
# 195    JGrand00691@work
# 196    WKanek09695@work
# 197     TChen08725@work
# 198    WMarbu01120@work
# 199    SSienk09418@work
# Name: Email, Length: 200, dtype: string

# %%
students['FullName'].str.len()
# Out:
# 0      13
# 1      19
# 2      14
# 3      12
# 4      11
#        ..
# 195    17
# 196    14
# 197    13
# 198    16
# 199    18
# Name: FullName, Length: 200, dtype: Int64

# %%
students['FullName'].str.contains('er')
# Out:
# 0      False
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 195    False
# 196    False
# 197    False
# 198     True
# 199    False
# Name: FullName, Length: 200, dtype: boolean

# %% [markdown]
# ### Split strings into columns

# %%
students['FullName'].str.split(' ', expand=True)
# Out:
#             0             1
# 0      Eunice        Ehmann
# 1      Hobert  Schoenberger
# 2    Nicholas         Sizer
# 3       Elvin        Foulks
# 4       Bruno         Viney
# ..        ...           ...
# 195     Judge   Grandinetti
# 196   Winston        Kaneko
# 197  Thaddeus          Chen
# 198    Wright     Marburger
# 199    Sidney   Sienkiewicz
#
# [200 rows x 2 columns]

# %% [markdown]
# ### Simple search in text columns

# %%
students.loc[students['FullName'].str.contains('er'), :]
# Out:
#      StudentID  FirstName      LastName  HSGPA  FYGPA Standing  \
# 1    202008560     Hobert  Schoenberger   2.27   2.05  average
# 2    202004948   Nicholas         Sizer   4.00   3.96     good
# 7    202005622      Leroy         Pasha   2.22   2.20  average
# 13   202005224  Ferdinand          Geil   2.67   2.78  average
# 23   202005164     Vernie       Teneyck   2.91   3.41     good
# 29   202001489   Everette            Ra   2.81   2.02  average
# 33   202006689      Wyatt   Vandervoort   2.56   1.69     poor
# 42   202005840    Spencer      Fielding   2.40   2.08  average
# 49   202001447      Perry          Jahn   3.31   3.39     good
# 55   202008194      Elton        Bjerke   2.52   2.34  average
# 57   202007898    Wilfrid        Traver   2.51   2.69  average
# 60   202001214   Benjamin   Brinkerhoff   2.64   2.44  average
# 64   202008249     Carter        Reiley   3.94   3.46     good
# 72   202000013    Wilbert      Mccawley   2.90   2.26  average
# 80   202005198      Clare      Laughery   2.93   3.18     good
# 82   202008907      Emery            Gu   1.39   1.45     poor
# 93   202004157      Bruce     Hottinger   3.43   3.14     good
# 95   202001826    Spencer    Delaughter   3.05   2.95  average
# 96   202002070     Murray       Woerner   3.22   2.56  average
# 101  202003610     Austin      Goertzen   3.83   3.59     good
# 103  202001550     Delmer           Yaw   3.03   2.97  average
# 105  202001449     Connie         Osier   3.10   3.14     good
# 111  202006780       Bert         Orban   3.45   2.43  average
# 120  202003784     Baxter      Frappier   2.92   2.76  average
# 121  202008176        Foy        Bohner   3.07   2.99  average
# 122  202005921     Casper         Alsip   2.71   2.42  average
# 125  202008490        Roe        Hooker   3.02   2.47  average
# 127  202000323     Hector        Mahler   3.27   2.18  average
# 137  202006720       Ocie       Stotler   3.25   3.09     good
# 145  202005426  Granville       Steiger   2.19   2.62  average
# 147  202007927     Shelby        Tigner   3.00   2.83  average
# 149  202000442      Lewis      Bratcher   3.54   2.64  average
# 157  202005538       Omer       Kurland   3.12   2.70  average
# 160  202005126     Bernie       Paolini   3.67   2.52  average
# 163  202006603     Miller           Yip   2.91   2.64  average
# 166  202009837     Theron       Jarquin   3.51   3.96     good
# 168  202006961   Frederic       Schrock   3.22   2.41  average
# 170  202005627      Abram        Serpas   2.08   1.88     poor
# 173  202005789      Early       Stauber   2.70   2.75  average
# 180  202009358  Henderson        Prough   2.62   2.46  average
# 182  202004769        Lon      Strauser   3.09   2.97  average
# 183  202007708     Glover         Portz   3.63   3.82     good
# 187  202007477     Verner          Puig   1.83   2.16  average
# 188  202000076  Jefferson      Shellman   3.59   2.76  average
# 189  202008437       Anna       Berkley   2.90   2.78  average
# 198  202001120     Wright     Marburger   2.41   2.11  average
#
#                  FullName                 Email
# 1     Hobert Schoenberger  HSchoe08560@work.com
# 2          Nicholas Sizer  NSizer04948@work.com
# 7             Leroy Pasha  LPasha05622@work.com
# 13         Ferdinand Geil   FGeil05224@work.com
# 23         Vernie Teneyck  VTeney05164@work.com
# 29            Everette Ra     ERa01489@work.com
# 33      Wyatt Vandervoort  WVande06689@work.com
# 42       Spencer Fielding  SField05840@work.com
# 49             Perry Jahn   PJahn01447@work.com
# 55           Elton Bjerke  EBjerk08194@work.com
# 57         Wilfrid Traver  WTrave07898@work.com
# 60   Benjamin Brinkerhoff  BBrink01214@work.com
# 64          Carter Reiley  CReile08249@work.com
# 72       Wilbert Mccawley  WMccaw00013@work.com
# 80         Clare Laughery  CLaugh05198@work.com
# 82               Emery Gu     EGu08907@work.com
# 93        Bruce Hottinger  BHotti04157@work.com
# 95     Spencer Delaughter  SDelau01826@work.com
# 96         Murray Woerner  MWoern02070@work.com
# 101       Austin Goertzen  AGoert03610@work.com
# 103            Delmer Yaw    DYaw01550@work.com
# 105          Connie Osier  COsier01449@work.com
# 111            Bert Orban  BOrban06780@work.com
# 120       Baxter Frappier  BFrapp03784@work.com
# 121            Foy Bohner  FBohne08176@work.com
# 122          Casper Alsip  CAlsip05921@work.com
# 125            Roe Hooker  RHooke08490@work.com
# 127         Hector Mahler  HMahle00323@work.com
# 137          Ocie Stotler  OStotl06720@work.com
# 145     Granville Steiger  GSteig05426@work.com
# 147         Shelby Tigner  STigne07927@work.com
# 149        Lewis Bratcher  LBratc00442@work.com
# 157          Omer Kurland  OKurla05538@work.com
# 160        Bernie Paolini  BPaoli05126@work.com
# 163            Miller Yip    MYip06603@work.com
# 166        Theron Jarquin  TJarqu09837@work.com
# 168      Frederic Schrock  FSchro06961@work.com
# 170          Abram Serpas  ASerpa05627@work.com
# 173         Early Stauber  EStaub05789@work.com
# 180      Henderson Prough  HProug09358@work.com
# 182          Lon Strauser  LStrau04769@work.com
# 183          Glover Portz  GPortz07708@work.com
# 187           Verner Puig   VPuig07477@work.com
# 188    Jefferson Shellman  JShell00076@work.com
# 189          Anna Berkley  ABerkl08437@work.com
# 198      Wright Marburger  WMarbu01120@work.com

# %%
students['FullName'].str.replace('er','or')
# Out:
# 0            Eunice Ehmann
# 1      Hobort Schoenborgor
# 2           Nicholas Sizor
# 3             Elvin Foulks
# 4              Bruno Viney
#               ...
# 195      Judge Grandinetti
# 196         Winston Kaneko
# 197          Thaddeus Chen
# 198       Wright Marburgor
# 199     Sidney Sienkiewicz
# Name: FullName, Length: 200, dtype: string
