# %% [markdown]
# The complete explanation for this notebook is at https://youranalystbuddy.com/correlation-analysis-on-two-numeric-columns/
#
# ## Loading data

# %%
import pandas as pd

students = pd.read_csv('students1000.csv')
students.head(n=3)
# Out:
#    StudentID  FirstName LastName                 Major  HighSchoolGPA  \
# 0  202303595     Baxter  Dengler      Computer Science           2.82
# 1  202309162  Christian   Wickey          Data Science           3.07
# 2  202306337     Lonnie    Wulff  Software Engineering           2.68
#
#    FamilyIncome State  AvgDailyStudyTime  TotalAbsence  FirstYearGPA
# 0         45013    WA               2.01          14.0          1.93
# 1        128358    GA               5.41           NaN          2.76
# 2        112392    GA               9.57          13.0          3.09

# %%
students['StudentID'] = students['StudentID'].astype('object')
students['StudentID'].dtype
# Out:
# dtype('O')

# %% [markdown]
# ## Scatter plots

# %%
import matplotlib.pyplot as plt
plt.figure()
pd.plotting.scatter_matrix(students, figsize=(10,10))
plt.show()

# %% [markdown]
# ## Correlation coefficients

# %%
students.corr()
# Out:
# <style type="text/css">
# #T_3658a_row0_col0, #T_3658a_row1_col1, #T_3658a_row2_col2, #T_3658a_row3_col3, #T_3658a_row4_col4, #T_3658a_row5_col5 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_3658a_row0_col1 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_3658a_row0_col2, #T_3658a_row1_col4, #T_3658a_row4_col1, #T_3658a_row4_col3, #T_3658a_row4_col5, #T_3658a_row5_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_3658a_row0_col3, #T_3658a_row2_col3 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_3658a_row0_col4 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_3658a_row0_col5 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_3658a_row1_col0, #T_3658a_row3_col0 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_3658a_row1_col2 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_3658a_row1_col3 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_3658a_row1_col5 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_3658a_row2_col0, #T_3658a_row4_col2 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_3658a_row2_col1 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_3658a_row2_col4 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_3658a_row2_col5 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_3658a_row3_col1 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_3658a_row3_col2 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_3658a_row3_col4 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_3658a_row3_col5 {
#   background-color: #08458a;
#   color: #f1f1f1;
# }
# #T_3658a_row4_col0 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_3658a_row5_col1 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_3658a_row5_col2 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_3658a_row5_col3 {
#   background-color: #08488e;
#   color: #f1f1f1;
# }
# #T_3658a_row5_col4 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# </style>
# <table id="T_3658a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3658a_level0_col0" class="col_heading level0 col0" >StudentID</th>
#       <th id="T_3658a_level0_col1" class="col_heading level0 col1" >HighSchoolGPA</th>
#       <th id="T_3658a_level0_col2" class="col_heading level0 col2" >FamilyIncome</th>
#       <th id="T_3658a_level0_col3" class="col_heading level0 col3" >AvgDailyStudyTime</th>
#       <th id="T_3658a_level0_col4" class="col_heading level0 col4" >TotalAbsence</th>
#       <th id="T_3658a_level0_col5" class="col_heading level0 col5" >FirstYearGPA</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3658a_level0_row0" class="row_heading level0 row0" >StudentID</th>
#       <td id="T_3658a_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_3658a_row0_col1" class="data row0 col1" >-0.004912</td>
#       <td id="T_3658a_row0_col2" class="data row0 col2" >-0.014622</td>
#       <td id="T_3658a_row0_col3" class="data row0 col3" >-0.003410</td>
#       <td id="T_3658a_row0_col4" class="data row0 col4" >0.069144</td>
#       <td id="T_3658a_row0_col5" class="data row0 col5" >-0.021349</td>
#     </tr>
#     <tr>
#       <th id="T_3658a_level0_row1" class="row_heading level0 row1" >HighSchoolGPA</th>
#       <td id="T_3658a_row1_col0" class="data row1 col0" >-0.004912</td>
#       <td id="T_3658a_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_3658a_row1_col2" class="data row1 col2" >0.019421</td>
#       <td id="T_3658a_row1_col3" class="data row1 col3" >0.434260</td>
#       <td id="T_3658a_row1_col4" class="data row1 col4" >-0.520424</td>
#       <td id="T_3658a_row1_col5" class="data row1 col5" >0.492234</td>
#     </tr>
#     <tr>
#       <th id="T_3658a_level0_row2" class="row_heading level0 row2" >FamilyIncome</th>
#       <td id="T_3658a_row2_col0" class="data row2 col0" >-0.014622</td>
#       <td id="T_3658a_row2_col1" class="data row2 col1" >0.019421</td>
#       <td id="T_3658a_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_3658a_row2_col3" class="data row2 col3" >0.000407</td>
#       <td id="T_3658a_row2_col4" class="data row2 col4" >-0.009694</td>
#       <td id="T_3658a_row2_col5" class="data row2 col5" >0.016689</td>
#     </tr>
#     <tr>
#       <th id="T_3658a_level0_row3" class="row_heading level0 row3" >AvgDailyStudyTime</th>
#       <td id="T_3658a_row3_col0" class="data row3 col0" >-0.003410</td>
#       <td id="T_3658a_row3_col1" class="data row3 col1" >0.434260</td>
#       <td id="T_3658a_row3_col2" class="data row3 col2" >0.000407</td>
#       <td id="T_3658a_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_3658a_row3_col4" class="data row3 col4" >-0.190153</td>
#       <td id="T_3658a_row3_col5" class="data row3 col5" >0.893033</td>
#     </tr>
#     <tr>
#       <th id="T_3658a_level0_row4" class="row_heading level0 row4" >TotalAbsence</th>
#       <td id="T_3658a_row4_col0" class="data row4 col0" >0.069144</td>
#       <td id="T_3658a_row4_col1" class="data row4 col1" >-0.520424</td>
#       <td id="T_3658a_row4_col2" class="data row4 col2" >-0.009694</td>
#       <td id="T_3658a_row4_col3" class="data row4 col3" >-0.190153</td>
#       <td id="T_3658a_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_3658a_row4_col5" class="data row4 col5" >-0.313092</td>
#     </tr>
#     <tr>
#       <th id="T_3658a_level0_row5" class="row_heading level0 row5" >FirstYearGPA</th>
#       <td id="T_3658a_row5_col0" class="data row5 col0" >-0.021349</td>
#       <td id="T_3658a_row5_col1" class="data row5 col1" >0.492234</td>
#       <td id="T_3658a_row5_col2" class="data row5 col2" >0.016689</td>
#       <td id="T_3658a_row5_col3" class="data row5 col3" >0.893033</td>
#       <td id="T_3658a_row5_col4" class="data row5 col4" >-0.313092</td>
#       <td id="T_3658a_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
