# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.sort(np.random.normal(0,1,(100,1)),axis=0)
y = 2*x + np.random.normal(0,1,(100,1))

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(x,y)
yh = lr.predict(x)

# %%
lr.score(x,y)
# Out:
# 0.7820156794625085

# %%
plt.figure(figsize=(4,4))
plt.scatter(x,y)
plt.plot(x,yh,c='red',linewidth=4)
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures

pf = PolynomialFeatures(degree=10)
x10 = pf.fit_transform(x)
lr.fit(x10,y)
yh10 = lr.predict(x10)

# %%
lr.score(x10,y)
# Out:
# 0.7976286523016524

# %%
plt.figure(figsize=(4,4))
plt.scatter(x,y)
plt.plot(x,yh10,c='red',linewidth=4)
plt.show()

# %%
pf = PolynomialFeatures(degree=20)
x20 = pf.fit_transform(x)
lr.fit(x20,y)
yh20 = lr.predict(x20)

# %%
lr.score(x20,y)
# Out:
# 0.8181724879790748

# %%
plt.figure(figsize=(4,4))
plt.scatter(x,y)
plt.plot(x,yh20,c='red',linewidth=4)
plt.show()

# %%
from sklearn.linear_model import Ridge

ridge = Ridge()
ridge.fit(x10,y)
yh10r = ridge.predict(x10)

plt.figure(figsize=(4,4))
plt.scatter(x,y)
plt.plot(x,yh10r,c='red',linewidth=4)
plt.show()

# %%
ridge = Ridge()
ridge.fit(x20,y)
yh20r = ridge.predict(x20)

plt.figure(figsize=(4,4))
plt.scatter(x,y)
plt.plot(x,yh20r,c='red',linewidth=4)
plt.show()
# Out:
# C:\Users\linhl\miniconda3\envs\tfbase\lib\site-packages\sklearn\linear_model\_ridge.py:212: LinAlgWarning: Ill-conditioned matrix (rcond=6.74171e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
